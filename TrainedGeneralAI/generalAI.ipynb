# %% [markdown]
# # Importando classes

# %%
# Torch
import torch
import torchvision.transforms as transforms
import torchvision
import torchvision.datasets as datasets
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import random_split, Subset

# CV2
# import cv2 # <- OpenCV (Biblioteca de Visão Computacional)

# Avaliação de resultados
from sklearn.metrics import accuracy_score

# Rodando scripts modularizados
# %run "../pyScripts/devFunctions.py"

# PIL
from PIL import Image

# Numpy
# import numpy as np

# Matplot
import matplotlib.pyplot as plt

# %% [markdown]
# # Definições

# %%
batch_size = 64 # <-- Batch é o tamanho do lote de imagens que serão processadas juntas
epoch = 8 # <- Quantidade de ciclos de treinamento
train_data = "/media/kaua-matheus/HD320/Data/Agroscope/Corn"
# test_data = "../../../GeneralData/test"
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Transform

# %% [markdown]
# ## Definindo as funções CV2
# Essas funções são as responsáveis por alguns filtros específicos que serão aplicados nas imagens, a fim de melhorar o aprendizado.

# %%
# # Função lambda que aplica o filtro Sobel
# sobel_transform = transforms.Lambda(
#     lambda img: Image.fromarray(
#         cv2.convertScaleAbs(
#             np.hypot(
#                 cv2.Sobel(np.array(img), cv2.CV_64F, 1, 0, ksize=3),
#                 cv2.Sobel(np.array(img), cv2.CV_64F, 0, 1, ksize=3)
#             )
#         )
#     )
# )

# %%
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    # transforms.Grayscale(1),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.GaussianBlur(5, 0.8),

    # sobel_transform,
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)), # Normalizando imagem para apenas um canal ao invés de 3 -> (0.5, 0.5, 0.5), (0.5, 0.5, 0.5)
])

# %% [markdown]
# ## Subset
# Usado somente para testes.

# %%
# train_set = datasets.ImageFolder(root=train_data, transform=transform)
# test_set = datasets.ImageFolder(root=test_data, transform=transform)

# num_train_samples = 2000
# num_test_samples = 500

# # randperm para amostras randomizadas
# train_indices = torch.randperm(len(train_set))[:num_train_samples]
# test_indices = torch.randperm(len(test_set))[:num_test_samples]

# train_subset = Subset(train_set, train_indices)
# test_subset = Subset(test_set, test_indices)

# train_loader = torch.utils.data.DataLoader(train_subset, batch_size=batch_size, shuffle=True)
# test_loader = torch.utils.data.DataLoader(test_subset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ## Dataset Principal

# %%
train_set = datasets.ImageFolder(root=train_data, transform=transform)
# test_set = datasets.ImageFolder(root=test_data, transform=transform)

train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle=True)
# test_loader = torch.utils.data.DataLoader(test_set, batch_size=batch_size, shuffle=True)

# %%
train_set * 0.5
# Out:
# Dataset ImageFolder
#     Number of datapoints: 2931
#     Root location: /media/kaua-matheus/HD320/Data/Agroscope/Corn
#     StandardTransform
# Transform: Compose(
#                Resize(size=(128, 128), interpolation=bilinear, max_size=None, antialias=True)
#                RandomHorizontalFlip(p=0.5)
#                RandomRotation(degrees=[-10.0, 10.0], interpolation=nearest, expand=False, fill=0)
#                GaussianBlur(kernel_size=(5, 5), sigma=(0.8, 0.8))
#                ToTensor()
#                Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
#            )

# %%
# Quantidade de amostras
train_loader.batch_sampler.sampler.num_samples
# Out:
# 2931

# %% [markdown]
# ### Mostrando as imagens do trainset

# %%
image = Image.open(train_set.imgs[3][0])
image_tensor = transform(image)

imshow(torchvision.utils.make_grid(image_tensor.unsqueeze(0)))

# %% [markdown]
# ### Debug do Sobel

# %%
# image = Image.open(train_set.imgs[3][0]).convert("L")
# sobel_image = sobel_transform(image)

# plt.imshow(sobel_image, cmap="gray")
# plt.title("Detecção de cantos - Sobel")
# plt.axis("off")
# plt.show()

# %% [markdown]
# # Criando as classes

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()

        # Construção das hidden layers
        # Alterado o valor da entrada para 3, visto que agora são 3 canais
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1) # 128
        self.bn1 = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1) # 64
        self.bn2 = nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3) # 30
        self.bn3 = nn.BatchNorm2d(128)

        self.pool = nn.MaxPool2d(2, 2) # 15
        # self.adaptative_pool = nn.AdaptiveAvgPool2d(7) <- Talvez Aplicar futuramente

        # Flatten
        self.fc1 = nn.Linear(128 * 15 * 15, 120)
        self.bn4 = nn.BatchNorm1d(120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 3)

        # Ativação GeLU
        self.gelu = nn.GELU()
    
    def forward(self, x):
        x = self.pool(F.gelu(self.bn1(self.conv1(x))))
        x = self.pool(F.gelu(self.bn2(self.conv2(x))))
        x = self.pool(F.gelu(self.bn3(self.conv3(x))))

        x = torch.flatten(x, 1)

        x = F.gelu(self.bn4(self.fc1(x)))
        x = F.gelu(self.fc2(x))
        x = self.fc3(x)

        return x

# %% [markdown]
# # Definindo o otimizador e a função de perda

# %%
Net = NeuralNetwork().to(DEVICE)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(Net.parameters(), lr=0.001, momentum=0.9)

# %% [markdown]
# # Treinando o modelo

# %%
for epoch in range(epoch):

    running_loss = 0.0

    for images, labels in train_loader:

        """
            Nesse caso, images é a representação em matriz da imagem.
            E labels é a representação de cada camada da CNN, se ela ativou ou não.
        """

        # Adquirindo entradas, "data" é uma lista [inputs, labels]
        images, labels = images.to(DEVICE), labels.to(DEVICE)

        # zerando os parâmetros dos gradientes
        optimizer.zero_grad()

        outputs = Net(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        
    print(f'[{epoch + 1}] loss: {running_loss / 2000:.3f}')

print("Treinamento concluído!")
# Out:
# [1] loss: 0.018
# [2] loss: 0.013
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 5
#       1 for epoch in range(epoch):
#       3     running_loss = 0.0
# ----> 5     for images, labels in train_loader:
#       7         """
#       8             Nesse caso, images é a representação em matriz da imagem.
#       9             E labels é a representação de cada camada da CNN, se ela ativou ou não.
#      10         """
#      12         # Adquirindo entradas, "data" é uma lista [inputs, labels]
#
# File ~/Documentos/Agroscope_IA/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:732, in _BaseDataLoaderIter.__next__(self)
#     729 if self._sampler_iter is None:
#     730     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     731     self._reset()  # type: ignore[call-arg]
# --> 732 data = self._next_data()
#     733 self._num_yielded += 1
#     734 if (
#     735     self._dataset_kind == _DatasetKind.Iterable
#     736     and self._IterableDataset_len_called is not None
#     737     and self._num_yielded > self._IterableDataset_len_called
#     738 ):
#
# File ~/Documentos/Agroscope_IA/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:788, in _SingleProcessDataLoaderIter._next_data(self)
#     786 def _next_data(self):
#     787     index = self._next_index()  # may raise StopIteration
# --> 788     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     789     if self._pin_memory:
#     790         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/Documentos/Agroscope_IA/.venv/lib/python3.12/site-packages/torch/utils/data/_utils/fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File ~/Documentos/Agroscope_IA/.venv/lib/python3.12/site-packages/torchvision/datasets/folder.py:245, in DatasetFolder.__getitem__(self, index)
#     237 """
#     238 Args:
#     239     index (int): Index
#    (...)    242     tuple: (sample, target) where target is class_index of the target class.
#     243 """
#     244 path, target = self.samples[index]
# --> 245 sample = self.loader(path)
#     246 if self.transform is not None:
#     247     sample = self.transform(sample)
#
# File ~/Documentos/Agroscope_IA/.venv/lib/python3.12/site-packages/torchvision/datasets/folder.py:284, in default_loader(path)
#     282     return accimage_loader(path)
#     283 else:
# --> 284     return pil_loader(path)
#
# File ~/Documentos/Agroscope_IA/.venv/lib/python3.12/site-packages/torchvision/datasets/folder.py:264, in pil_loader(path)
#     262 with open(path, "rb") as f:
#     263     img = Image.open(f)
# --> 264     return img.convert("RGB")
#
# File ~/Documentos/Agroscope_IA/.venv/lib/python3.12/site-packages/PIL/Image.py:972, in Image.convert(self, mode, matrix, dither, palette, colors)
#     920 def convert(
#     921     self,
#     922     mode: str | None = None,
#    (...)    926     colors: int = 256,
#     927 ) -> Image:
#     928     """
#     929     Returns a converted copy of this image. For the "P" mode, this
#     930     method translates pixels through the palette.  If mode is
#    (...)    969     :returns: An :py:class:`~PIL.Image.Image` object.
#     970     """
# --> 972     self.load()
#     974     has_transparency = "transparency" in self.info
#     975     if not mode and self.mode == "P":
#     976         # determine default mode
#
# File ~/Documentos/Agroscope_IA/.venv/lib/python3.12/site-packages/PIL/ImageFile.py:394, in ImageFile.load(self)
#     391         raise OSError(msg)
#     393 b = b + s
# --> 394 n, err_code = decoder.decode(b)
#     395 if n < 0:
#     396     break
#
# KeyboardInterrupt:

# %% [markdown]
# # Avaliando o modelo

# %%
Net.eval()
all_preds = []
all_labels = []

with torch.no_grad():  # Desativa o cálculo de gradientes para economizar memória
    for images, labels in test_loader:
        images, labels = images.to(DEVICE), labels.to(DEVICE)
        outputs = Net(images)
        _, predicted = torch.max(outputs, 1)  # Obtém a classe com maior probabilidade
        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

accuracy = accuracy_score(all_labels, all_preds)
print(f"Accuracy of the model on the test set: {accuracy * 100:.2f}%")
# Out:
# Accuracy of the model on the test set: 97.11%

# %% [markdown]
# # Salvando Modelo

# %%
torch.save(Net.state_dict(), "./Models/generalAI_v2_1.pth")
