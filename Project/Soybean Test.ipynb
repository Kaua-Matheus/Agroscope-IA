# %% [markdown]
# # Importando classes

# %%
# Torch
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import torchvision
import torchvision.datasets as datasets
import torch.optim as optim
from torch.utils.data import random_split, Subset

# Módulos Próprios
from utils.devFunctions import Imshow
from utils.models import NeuralNetwork

# Numpy
import numpy as np

# PIL
from PIL import Image
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Torch
# ----> 2 import torch
#       3 import torch.nn as nn
#       4 import torchvision.transforms as transforms
#
# File ~/Documentos/Agroscope_IA/.venv/lib/python3.12/site-packages/torch/__init__.py:2276
#    2272 sys.modules.setdefault(f"{__name__}.classes", classes)
#    2274 # quantization depends on torch.fx and torch.ops
#    2275 # Import quantization
# -> 2276 from torch import quantization as quantization  # usort: skip
#    2278 # Import the quasi random sampler
#    2279 from torch import quasirandom as quasirandom  # usort: skip
#
# File ~/Documentos/Agroscope_IA/.venv/lib/python3.12/site-packages/torch/quantization/__init__.py:2
#       1 # mypy: allow-untyped-defs
# ----> 2 from .fake_quantize import *  # noqa: F403
#       3 from .fuse_modules import fuse_modules
#       4 from .fuser_method_mappings import *  # noqa: F403
#
# File ~/Documentos/Agroscope_IA/.venv/lib/python3.12/site-packages/torch/quantization/fake_quantize.py:10
#       1 # flake8: noqa: F401
#       2 r"""
#       3 This file is in the process of migration to `torch/ao/quantization`, and
#       4 is kept here for compatibility while the migration process is ongoing.
#    (...)      7 here.
#       8 """
# ---> 10 from torch.ao.quantization.fake_quantize import (
#      11     _is_fake_quant_script_module,
#      12     _is_per_channel,
#      13     _is_per_tensor,
#      14     _is_symmetric_quant,
#      15     default_fake_quant,
#      16     default_fixed_qparams_range_0to1_fake_quant,
#      17     default_fixed_qparams_range_neg1to1_fake_quant,
#      18     default_fused_act_fake_quant,
#      19     default_fused_per_channel_wt_fake_quant,
#      20     default_fused_wt_fake_quant,
#      21     default_histogram_fake_quant,
#      22     default_per_channel_weight_fake_quant,
#      23     default_weight_fake_quant,
#      24     disable_fake_quant,
#      25     disable_observer,
#      26     enable_fake_quant,
#      27     enable_observer,
#      28     FakeQuantize,
#      29     FakeQuantizeBase,
#      30     FixedQParamsFakeQuantize,
#      31     FusedMovingAvgObsFakeQuantize,
#      32 )
#
# File ~/Documentos/Agroscope_IA/.venv/lib/python3.12/site-packages/torch/ao/quantization/__init__.py:13
#      11 from .fuser_method_mappings import *  # noqa: F403
#      12 from .observer import *  # noqa: F403
# ---> 13 from .pt2e._numeric_debugger import (  # noqa: F401
#      14     compare_results,
#      15     CUSTOM_KEY,
#      16     extract_results_from_loggers,
#      17     generate_numeric_debug_handle,
#      18     NUMERIC_DEBUG_HANDLE_KEY,
#      19     prepare_for_propagation_comparison,
#      20 )
#      21 from .pt2e.export_utils import (
#      22     _allow_exported_model_train_eval as allow_exported_model_train_eval,
#      23     _move_exported_model_to_eval as move_exported_model_to_eval,
#      24     _move_exported_model_to_train as move_exported_model_to_train,
#      25 )
#      26 from .qconfig import *  # noqa: F403
#
# File ~/Documentos/Agroscope_IA/.venv/lib/python3.12/site-packages/torch/ao/quantization/pt2e/_numeric_debugger.py:9
#       7 import torch
#       8 from torch.ao.ns.fx.utils import compute_sqnr
# ----> 9 from torch.ao.quantization.pt2e.graph_utils import bfs_trace_with_node_process
#      10 from torch.export import ExportedProgram
#      11 from torch.fx import GraphModule, Node
#
# File ~/Documentos/Agroscope_IA/.venv/lib/python3.12/site-packages/torch/ao/quantization/pt2e/graph_utils.py:9
#       6 from typing import Any, Callable, Optional, Union
#       8 import torch
# ----> 9 from torch.export import ExportedProgram
#      10 from torch.fx import Node
#      11 from torch.fx.passes.utils.source_matcher_utils import (
#      12     check_subgraphs_connected,
#      13     get_source_partitions,
#      14     SourcePartition,
#      15 )
#
# File ~/Documentos/Agroscope_IA/.venv/lib/python3.12/site-packages/torch/export/__init__.py:42
#      39 # To make sure export specific custom ops are loaded
#      40 import torch.export.custom_ops
# ---> 42 from .decomp_utils import CustomDecompTable
#      43 from .dynamic_shapes import AdditionalInputs, Constraint, Dim, dims, ShapesCollection
#      44 from .exported_program import (
#      45     default_decompositions,
#      46     ExportedProgram,
#      47     ModuleCallEntry,
#      48     ModuleCallSignature,
#      49 )
#
# File ~/Documentos/Agroscope_IA/.venv/lib/python3.12/site-packages/torch/export/decomp_utils.py:5
#       2 from typing import Callable
#       4 import torch
# ----> 5 from torch._export.utils import (
#       6     _collect_all_valid_cia_ops,
#       7     _collect_all_valid_cia_ops_for_aten_namespace,
#       8     _get_decomp_for_cia,
#       9     _is_aten_op,
#      10 )
#      13 __all__ = ["CustomDecompTable"]
#      16 """
#      17 Core ATen ops with Composite Implicit Autograd dispatch that should be excluded from decomposition
#      18 by default. The decomposition logic should eventually exclude all core-tagged CIA ops, but until all
#      19 backends are ready, this list allows opt-in one at a time.
#      20 """
#
# File ~/Documentos/Agroscope_IA/.venv/lib/python3.12/site-packages/torch/_export/__init__.py:48
#      45 from torch.fx.experimental.proxy_tensor import make_fx
#      46 from torch.fx.graph import _PyTreeCodeGen, _PyTreeInfo
# ---> 48 from .wrappers import _wrap_submodules
#      49 from .utils import _materialize_cpp_cia_ops
#      51 if TYPE_CHECKING:
#
# File ~/Documentos/Agroscope_IA/.venv/lib/python3.12/site-packages/torch/_export/wrappers.py:10
#       8 from torch._C import DispatchKey
#       9 from torch._export.utils import _maybe_find_pre_dispatch_tf_mode_for_export
# ---> 10 from torch._higher_order_ops.flat_apply import (
#      11     _ConstantFunction,
#      12     flat_apply,
#      13     to_graphable,
#      14 )
#      15 from torch._higher_order_ops.strict_mode import strict_mode
#      16 from torch._higher_order_ops.utils import autograd_not_implemented
#
# File ~/Documentos/Agroscope_IA/.venv/lib/python3.12/site-packages/torch/_higher_order_ops/__init__.py:17
#      15 from torch._higher_order_ops.executorch_call_delegate import executorch_call_delegate
#      16 from torch._higher_order_ops.flat_apply import flat_apply
# ---> 17 from torch._higher_order_ops.flex_attention import (
#      18     flex_attention,
#      19     flex_attention_backward,
#      20 )
#      21 from torch._higher_order_ops.foreach_map import _foreach_map, foreach_map
#      22 from torch._higher_order_ops.hints_wrap import hints_wrapper
#
# File ~/Documentos/Agroscope_IA/.venv/lib/python3.12/site-packages/torch/_higher_order_ops/flex_attention.py:31
#      25 from torch.fx.experimental.proxy_tensor import (
#      26     make_fx,
#      27     ProxyTorchDispatchMode,
#      28     track_tensor_tree,
#      29 )
#      30 from torch.fx.graph_module import GraphModule
# ---> 31 from torch.utils.checkpoint import _CachedTorchDispatchMode, _CachingTorchDispatchMode
#      34 # Duplicate of _inductor/kernel/flex_attention.py to avoid circular import
#      35 def _construct_strides(
#      36     sizes: Sequence[int],
#      37     fill_order: Sequence[int],
#      38 ) -> Sequence[int]:
#
# File ~/Documentos/Agroscope_IA/.venv/lib/python3.12/site-packages/torch/utils/checkpoint.py:13
#      10 from weakref import ReferenceType
#      12 import torch
# ---> 13 import torch.fx.traceback as fx_traceback
#      14 from torch.utils._pytree import tree_map
#      15 from torch.testing._internal.logging_tensor import capture_logs, LoggingTensorMode
#
# File <frozen importlib._bootstrap>:471, in _lock_unlock_module(name)
#
# File <frozen importlib._bootstrap>:311, in acquire(self)
#
# File <frozen importlib._bootstrap>:158, in __init__(self, thread_id, lock)
#
# KeyboardInterrupt:

# %% [markdown]
# # Definições

# %%
BATCH_SIZE = 128
EPOCH = 5

DATA_PATH = "/media/kaua-matheus/HD320/Data/Agroscope/Especialista_Tratado/Soybean"

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
print(f"Dispositivo Usado: {"GPU" if DEVICE.type == "cuda" else "CPU"}")

# %% [markdown]
# ## Transform

# %%
transform = transforms.Compose([
    transforms.Resize((198, 198)),
    transforms.RandomRotation(4),
    transforms.RandomHorizontalFlip(),
    transforms.CenterCrop((192, 192)),

    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
])

# %% [markdown]
# ## Dataset Principal

# %%
import random
full_dataset = datasets.ImageFolder(root=DATA_PATH, transform=transform)

# %%
class_indices = {0: [], 1: [], 2: []}

for idx, (_, label) in enumerate(full_dataset.imgs):
    class_indices[label].append(idx)

# %%
max_samples = 533 # Trocar max samples para corn
balanced_indices = []

for class_label, indices in class_indices.items():
    if len(indices) > max_samples:
        random.shuffle(indices)
        selected_indices = indices[:max_samples]
    else:
        selected_indices = indices

    balanced_indices.extend(selected_indices)
    print(f"Class {class_label}: {len(selected_indices)}")

random.shuffle(balanced_indices)
balanced_dataset = Subset(full_dataset, balanced_indices)

# %%
train_size = int(0.8 * len(balanced_dataset))
test_size = len(balanced_dataset) - train_size

# %%
print(f"All Dataset: {len(balanced_dataset)}")
print(f"Train (80%): {train_size}")
print(f"Test (20%): {test_size}")

# %%
train_dataset, test_dataset = random_split(balanced_dataset, [train_size, test_size])

# %%
# Podemos paralelizar usando persistent_workers=True

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, num_workers=4, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=BATCH_SIZE, num_workers=4, shuffle=True)

# %% [markdown]
# ### Mostrando as imagens do trainset

# %%
image = Image.open(balanced_dataset.dataset.imgs[np.random.randint(0, len(balanced_dataset.dataset.imgs)-1)][0])
image_tensor = transform(image)

Imshow(torchvision.utils.make_grid(image_tensor.unsqueeze(0))) # type: ignore

# %% [markdown]
# # Definindo o otimizador e a função de perda

# %%
Net = NeuralNetwork().to(DEVICE)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(Net.parameters(), lr=0.008, momentum=0.9)

# %% [markdown]
# # Treinando o modelo

# %%
for epoch in range(EPOCH):

    running_loss = 0.0

    for images, labels in train_loader:

        """
            Nesse caso, images é a representação em matriz da imagem.
            E labels é a representação de cada camada da CNN, se ela ativou ou não.
        """

        # Adquirindo entradas, "data" é uma lista [inputs, labels]
        images, labels = images.to(DEVICE), labels.to(DEVICE)

        # zerando os parâmetros dos gradientes
        optimizer.zero_grad()

        outputs = Net(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        
    print(f'[{epoch + 1}] loss: {running_loss / 2000:.3f}')

print("Treinamento concluído!")

# %% [markdown]
# # Avaliando o modelo

# %%
# Avaliação de resultados
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, roc_auc_score
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %%
Net.eval()
all_preds = []
all_labels = []
all_probs = []

with torch.no_grad():  # Desativa o cálculo de gradientes para economizar memória
    for images, labels in test_loader:
        images, labels = images.to(DEVICE), labels.to(DEVICE)
        outputs = Net(images)

        probabilities = torch.softmax(outputs, dim=1)
        all_probs.extend(probabilities.cpu().numpy())

        _, predicted = torch.max(outputs, 1)
        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())


accuracy = accuracy_score(all_labels, all_preds)
print(f"Accuracy of the model on the test set: {accuracy * 100:.2f}%")

# %% [markdown]
# ## Testes Extras

# %% [markdown]
# ### Confusion Matrix
# A matrix de confusão mostra onde o modelo mais se confunde, ou seja, quais classes mais se "parecem" com outras, segundo o modelo.
#
# Na nossa análise, podemos reparar que o modelo mais confunde a ferrugem comum com os outros (saudável e polissora), sendo assim, mais padrões necessitam ser identificados, principalmente na ferrugem comum para melhorar a identificação.\
# De todos os erros (27 ao todo), 26 foram na ferrugem comum, confundindo-a com saudável ou polissora.

# %%
confusion_matrix_eval = confusion_matrix(all_labels, all_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=confusion_matrix_eval, display_labels=full_dataset.classes)
disp.plot()
plt.show()

# %% [markdown]
# ### Precision, Recall e F1-Score
# Necessário para identificar ponderação nas predições. Em alguns datasets, a quantidade de registros de uma classe pode ser maior do que outras, isso significa um desbalanço nos dados, portanto, uma ponderação de acerto deve ser aplicada.\
# Por conta disso, F1-Score avalia a média harmônica da precisão e do recall, visando encontrar um indicador de bom equilibrio entre corretamente positivos e todos os positivos.\
# O valor de F1 varia de 0 e 1, onde 1 é o melhor.

# %%
f1 = f1_score(all_labels, all_preds, average=None)
f1

# %% [markdown]
# ### Roc e Auc

# %%
all_probs = np.array(all_probs)

# %%
roc_auc = roc_auc_score(all_labels, all_probs, multi_class="ovo")
print(f"Roc-Auc Score: {roc_auc:.4f}")

# %%
roc_auc_macro = roc_auc_score(all_labels, all_probs, multi_class="ovr")
print(f"Roc-Auc Macro: {roc_auc_macro:.4f}")

# %% [markdown]
# # Salvando Modelo

# %%
torch.save(Net.state_dict(), "./Models/New Models/Expert/SoybeanAI_v1.pth")

# %% [markdown]
# # Carregando Modelo

# %%
Net = NeuralNetwork().to(DEVICE)
Net.load_state_dict(torch.load("./Models/New Models/Expert/SoybeanAI_v1.pth"))
Net.eval()

# %% [markdown]
# # Testes Extras
# Os testes extras visam identificar se o modelo de fato é capaz de generalizar e identificar padrões, mesmo em imagens cheias de ruído e defeitos.

# %%
import cv2

# %%
sobel_transform = transforms.Lambda(
    lambda img: Image.fromarray(
        cv2.convertScaleAbs(
            np.hypot(
                cv2.Sobel(np.array(img), cv2.CV_64F, 1, 0, ksize=3),
                cv2.Sobel(np.array(img), cv2.CV_64F, 0, 1, ksize=3)
            )
        )
    )
)

# %%
jitter = transforms.ColorJitter(brightness=.5, hue=.3)

# %%
test_root = "/media/kaua-matheus/HD320/Data/Agroscope/Teste_Especialista/Soybean"

transform_high = transforms.Compose([
    transforms.Resize((198, 198)),
    #transforms.RandomRotation(2),
    transforms.RandomHorizontalFlip(),
    transforms.CenterCrop((192, 192)),

    jitter,
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)), # Normalizando imagem para apenas um canal ao invés de 3 -> (0.5, 0.5, 0.5), (0.5, 0.5, 0.5)
])

# %%
test_base = datasets.ImageFolder(root=test_root, transform=transform)
test_high = datasets.ImageFolder(root=test_root, transform=transform_high)

# %%
image = Image.open(test_base.imgs[np.random.randint(0, len(test_base.imgs)-1)][0])
image_tensor = transform(image)

Imshow(torchvision.utils.make_grid(image_tensor.unsqueeze(0)), "Default") # type: ignore

# %%
image = Image.open(test_high.imgs[np.random.randint(0, len(test_high.imgs)-1)][0])
image_tensor = transform_high(image)

Imshow(torchvision.utils.make_grid(image_tensor.unsqueeze(0)), "Higher Filters") # type: ignore

# %%
train_loader_base = torch.utils.data.DataLoader(test_base, batch_size=BATCH_SIZE, num_workers=4, shuffle=True)
train_loader_high = torch.utils.data.DataLoader(test_high, batch_size=BATCH_SIZE, num_workers=4, shuffle=True)

# %%
preds_base = list()
preds_high = list()

labels_base = list()
labels_high = list()

probs_base = list()
probs_high = list()

# %%
with torch.no_grad():
    for images, labels in train_loader_base:
        images, labels = images.to(DEVICE), labels.to(DEVICE)
        outputs = Net(images)

        probabilities = torch.softmax(outputs, dim=1)
        probs_base.extend(probabilities.cpu().numpy())

        _, predicted = torch.max(outputs, 1)
        preds_base.extend(predicted.cpu().numpy())
        labels_base.extend(labels.cpu().numpy())

accuracy = accuracy_score(labels_base, preds_base)
print(f"Accuracy of the model on the test set: {accuracy * 100:.2f}%")

# %%
with torch.no_grad():
    for images, labels in train_loader_high:
        images, labels = images.to(DEVICE), labels.to(DEVICE)
        outputs = Net(images)

        probabilities = torch.softmax(outputs, dim=1)
        probs_high.extend(probabilities.cpu().numpy())

        _, predicted = torch.max(outputs, 1)
        preds_high.extend(predicted.cpu().numpy())
        labels_high.extend(labels.cpu().numpy())

accuracy = accuracy_score(labels_high, preds_high)
print(f"Accuracy of the model on the test set: {accuracy * 100:.2f}%")
