# %% [markdown]
# ## Salvando Imagem Fatiada
# Usando CropImage podemos fazer o pre-processamento de uma imagem, selecionando apenas o que é interessante de se utilizar.

# %%
import os

from utils.devFunctions import CropImage
from dotenv import load_dotenv

load_dotenv()

# %%
PATH_ENTRY = os.getenv("PATH_ENTRY")
PATH_EXIT = os.getenv("PATH_EXIT")

# %%
CropImage(PATH_ENTRY, PATH_EXIT)
